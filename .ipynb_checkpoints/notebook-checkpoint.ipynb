# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import idx2numpy
import scipy
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications.xception import decode_predictions
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2023-01-24 23:28:29.440174: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
path = './split/train/alpine_sea_holly'
name = 'image_06972.jpg'
fullname = f'{path}/{name}'
img = load_img(fullname, target_size=(299,299))
x = np.array(img)
x.shape
# Out:
# (299, 299, 3)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %% [markdown]
# ## Using pre-trained neural network

# %%
model = Xception(weights='imagenet', input_shape=(299, 299, 3))
X = np.array([x])
X.shape
# Out:
# 2023-01-23 17:34:42.355704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-23 17:34:42.361809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-23 17:34:42.362405: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-23 17:34:42.363402: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# ...

# %%
X = preprocess_input(X)
pred = model.predict(X)
# Out:
# 2023-01-23 17:34:45.999810: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2023-01-23 17:34:46.623113: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-23 17:34:46.623951: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-23 17:34:46.623990: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2023-01-23 17:34:46.625051: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-01-23 17:34:46.625140: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# ...

# %%
decode_predictions(pred)
# Out:
# [[('n07730033', 'cardoon', 0.665376),
#   ('n03991062', 'pot', 0.054304592),
#   ('n01914609', 'sea_anemone', 0.04037478),
#   ('n02319095', 'sea_urchin', 0.028044622),
#   ('n11939491', 'daisy', 0.0275863)]]

# %% [markdown]
# ## Training Xception with the image dataset.

# %%
train_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_ds = train_gen.flow_from_directory('./split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False, class_mode='categorical')
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.

# %%
train_ds.class_indices
# Out:
# {'alpine_sea_holly': 0,
#  'anthurium': 1,
#  'artichoke': 2,
#  'azalea': 3,
#  'ball_moss': 4,
#  'balloon_flower': 5,
#  'barbeton_daisy': 6,
#  'bearded_iris': 7,
#  'bee_balm': 8,
#  'bird_of_paradise': 9,
#  'bishop_of_llandaff': 10,
#  'black-eyed_susan': 11,
#  'blackberry_lily': 12,
#  'blanket_flower': 13,
#  'bolero_deep_blue': 14,
#  'bougainvillea': 15,
#  'bromelia': 16,
#  'buttercup': 17,
#  'californian_poppy': 18,
#  'camellia': 19,
#  'canna_lily': 20,
#  'canterbury_bells': 21,
#  'cape_flower': 22,
#  'carnation': 23,
#  'cautleya_spicata': 24,
#  'clematis': 25,
#  'colts_foot': 26,
#  'columbine': 27,
#  'common_dandelion': 28,
#  'corn_poppy': 29,
#  'cyclamen': 30,
#  'daffodil': 31,
#  'desert_rose': 32,
#  'english_marigold': 33,
#  'fire_lily': 34,
#  'foxglove': 35,
#  'frangipani': 36,
#  'fritillary': 37,
#  'garden_phlox': 38,
#  'gaura': 39,
#  'gazania': 40,
#  'geranium': 41,
#  'giant_white_arum_lily': 42,
#  'globe-flower': 43,
# ...

# %%
base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)

base_model.trainable=False

inputs = keras.Input(shape=(150, 150, 3))

base = base_model(inputs, training=False)

vectors = keras.layers.GlobalAveragePooling2D()(base)

outputs = keras.layers.Dense(102)(vectors)

model = keras.Model(inputs, outputs)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.01)

loss = keras.losses.CategoricalCrossentropy(from_logits=True)

model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

# %%
info = model.fit(train_ds, epochs=10, validation_data=val_ds)
# Out:
# Epoch 1/10
# 153/153 [==============================] - 39s 234ms/step - loss: 2.8195 - accuracy: 0.5166 - val_loss: 1.7981 - val_accuracy: 0.6598
# Epoch 2/10
# 153/153 [==============================] - 30s 199ms/step - loss: 0.7995 - accuracy: 0.8022 - val_loss: 1.6821 - val_accuracy: 0.7110
# Epoch 3/10
# 153/153 [==============================] - 31s 200ms/step - loss: 0.4260 - accuracy: 0.8820 - val_loss: 1.5360 - val_accuracy: 0.7303
# Epoch 4/10
# 153/153 [==============================] - 31s 201ms/step - loss: 0.2622 - accuracy: 0.9247 - val_loss: 1.8408 - val_accuracy: 0.7147
# Epoch 5/10
# 153/153 [==============================] - 31s 200ms/step - loss: 0.1890 - accuracy: 0.9446 - val_loss: 1.8652 - val_accuracy: 0.7203
# Epoch 6/10
# 153/153 [==============================] - 31s 200ms/step - loss: 0.2374 - accuracy: 0.9391 - val_loss: 1.7496 - val_accuracy: 0.7459
# Epoch 7/10
# ...

# %%
plt.plot(info.history['accuracy'], label='train')
plt.plot(info.history['val_accuracy'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ## Adjusting learning rate

# %%
def make_model(learning_rate=0.01):
	base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)
	base_model.trainable=False
	inputs = keras.Input(shape=(150, 150, 3))
	base = base_model(inputs, training=False)
	vectors = keras.layers.GlobalAveragePooling2D()(base)
	outputs = keras.layers.Dense(102)(vectors)
	model = keras.Model(inputs, outputs)
	optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
	loss = keras.losses.CategoricalCrossentropy(from_logits=True)
	model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
	return model

# %%
scores = {}

for lr in [0.0001, 0.001, 0.01, 0.1, 1]:
	print(lr)
	model = make_model(learning_rate=lr)
	info = model.fit(train_ds, epochs=10, validation_data=val_ds)
	scores[lr] = info.history
	print()
	print()
# Out:
# 0.0001
# Epoch 1/10
# 153/153 [==============================] - 33s 205ms/step - loss: 4.1291 - accuracy: 0.1067 - val_loss: 3.5454 - val_accuracy: 0.2266
# Epoch 2/10
# 153/153 [==============================] - 30s 200ms/step - loss: 3.1362 - accuracy: 0.3240 - val_loss: 2.8570 - val_accuracy: 0.4045
# Epoch 3/10
# 153/153 [==============================] - 30s 199ms/step - loss: 2.5275 - accuracy: 0.4963 - val_loss: 2.4149 - val_accuracy: 0.5019
# Epoch 4/10
# 153/153 [==============================] - 31s 200ms/step - loss: 2.1167 - accuracy: 0.5886 - val_loss: 2.1161 - val_accuracy: 0.5755
# Epoch 5/10
# 153/153 [==============================] - 30s 197ms/step - loss: 1.8250 - accuracy: 0.6629 - val_loss: 1.9022 - val_accuracy: 0.6086
# Epoch 6/10
# 153/153 [==============================] - 30s 198ms/step - loss: 1.6082 - accuracy: 0.7078 - val_loss: 1.7428 - val_accuracy: 0.6380
# Epoch 7/10
# ...

# %%
for lr, hist in scores.items():
    plt.plot(hist['accuracy'], label=lr)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
plt.xticks(np.arange(10))
plt.legend()

# %%
for lr, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=lr)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
plt.xticks(np.arange(10))
plt.legend()

# %%
learning_rate = 0.001

# %% [markdown]
# ## Adding more layers

# %%
def make_model(learning_rate=0.01, size_inner=100):
        base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)
        base_model.trainable=False
        inputs = keras.Input(shape=(150, 150, 3))
        base = base_model(inputs, training=False)
        vectors = keras.layers.GlobalAveragePooling2D()(base)
        inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
        outputs = keras.layers.Dense(102)(inner)
        model = keras.Model(inputs, outputs)
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        loss = keras.losses.CategoricalCrossentropy(from_logits=True)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        return model

# %%
learning_rate = 0.001

scores = {}

for size in [10, 100, 1000, 2000]:
	print(size)
	model = make_model(learning_rate=learning_rate, size_inner=size)
	info = model.fit(train_ds, epochs=15, validation_data=val_ds)
	scores[size] = info.history
	print()
	print()
# Out:
# 10
# Epoch 1/15
# 153/153 [==============================] - 33s 205ms/step - loss: 4.3325 - accuracy: 0.0700 - val_loss: 3.9419 - val_accuracy: 0.1361
# Epoch 2/15
# 153/153 [==============================] - 31s 200ms/step - loss: 3.5671 - accuracy: 0.1978 - val_loss: 3.2675 - val_accuracy: 0.2422
# Epoch 3/15
# 153/153 [==============================] - 30s 199ms/step - loss: 2.9565 - accuracy: 0.2969 - val_loss: 2.8399 - val_accuracy: 0.3196
# Epoch 4/15
# 153/153 [==============================] - 30s 199ms/step - loss: 2.5989 - accuracy: 0.3484 - val_loss: 2.6046 - val_accuracy: 0.3489
# Epoch 5/15
# 153/153 [==============================] - 31s 199ms/step - loss: 2.3757 - accuracy: 0.3892 - val_loss: 2.4580 - val_accuracy: 0.3752
# Epoch 6/15
# 153/153 [==============================] - 30s 199ms/step - loss: 2.2262 - accuracy: 0.4259 - val_loss: 2.3637 - val_accuracy: 0.3945
# Epoch 7/15
# ...

# %%
for size, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=size)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
plt.xticks(np.arange(10))
plt.legend()

# %%
size = 1000

# %% [markdown]
# ## Dropout and Regularisation

# %%
def make_model(learning_rate=0.01, size_inner=100, droprate=0.5):
        base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)
        base_model.trainable=False
        inputs = keras.Input(shape=(150, 150, 3))
        base = base_model(inputs, training=False)
        vectors = keras.layers.GlobalAveragePooling2D()(base)
        inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
        drop = keras.layers.Dropout(droprate)(inner)
        outputs = keras.layers.Dense(102)(drop)
        model = keras.Model(inputs, outputs)
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        loss = keras.losses.CategoricalCrossentropy(from_logits=True)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        return model

# %%
learning_rate = 0.001
size = 1000

scores = {}

for droprate in [0.0, 0.2, 0.5, 0.8]:
	print(droprate)
	model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
	info = model.fit(train_ds, epochs=50, validation_data=val_ds)
	scores[droprate] = info.history
	print()
	print()
# Out:
# 0.0
# Epoch 1/50
# 153/153 [==============================] - 33s 205ms/step - loss: 2.1016 - accuracy: 0.4936 - val_loss: 1.2488 - val_accuracy: 0.6704
# Epoch 2/50
# 153/153 [==============================] - 30s 198ms/step - loss: 0.7708 - accuracy: 0.7881 - val_loss: 1.0759 - val_accuracy: 0.7104
# Epoch 3/50
# 153/153 [==============================] - 31s 201ms/step - loss: 0.4389 - accuracy: 0.8740 - val_loss: 1.0413 - val_accuracy: 0.7228
# Epoch 4/50
# 153/153 [==============================] - 30s 199ms/step - loss: 0.2505 - accuracy: 0.9356 - val_loss: 0.9395 - val_accuracy: 0.7484
# Epoch 5/50
# 153/153 [==============================] - 31s 201ms/step - loss: 0.1549 - accuracy: 0.9625 - val_loss: 0.9421 - val_accuracy: 0.7603
# Epoch 6/50
# 153/153 [==============================] - 31s 199ms/step - loss: 0.0948 - accuracy: 0.9797 - val_loss: 0.9192 - val_accuracy: 0.7653
# Epoch 7/50
# ...

# %%
for droprate, hist in scores.items():
    plt.plot(hist['val_accuracy'], label=droprate)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
plt.xticks(np.arange(10))
plt.legend()

# %% [markdown]
# ## Testing with data augmentation

# %% [markdown]
# #### Dropout didn't really improve things and the original database is a bit small, generating new variations of images may be the way to go.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=None,
    #shear_range=10.0,
    #zoom_range=0.1,
    vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')
# Out:
# Found 4874 images belonging to 102 classes.

# %%
def make_model(learning_rate=0.01, size_inner=100, droprate=0.5):
        base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)
        base_model.trainable=False
        inputs = keras.Input(shape=(150, 150, 3))
        base = base_model(inputs, training=False)
        vectors = keras.layers.GlobalAveragePooling2D()(base)
        inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
        drop = keras.layers.Dropout(droprate)(inner)
        outputs = keras.layers.Dense(102)(drop)
        model = keras.Model(inputs, outputs)
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        loss = keras.losses.CategoricalCrossentropy(from_logits=True)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        return model

# %%
learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores[droprate] = info.history
# Out:
# Epoch 1/50
# 153/153 [==============================] - 35s 212ms/step - loss: 2.2564 - accuracy: 0.4604 - val_loss: 1.3966 - val_accuracy: 0.6236
# Epoch 2/50
# 153/153 [==============================] - 31s 203ms/step - loss: 0.9622 - accuracy: 0.7370 - val_loss: 1.1228 - val_accuracy: 0.6866
# Epoch 3/50
# 153/153 [==============================] - 31s 205ms/step - loss: 0.6840 - accuracy: 0.8049 - val_loss: 0.9239 - val_accuracy: 0.7353
# Epoch 4/50
# 153/153 [==============================] - 31s 203ms/step - loss: 0.4932 - accuracy: 0.8619 - val_loss: 0.9620 - val_accuracy: 0.7559
# Epoch 5/50
# 153/153 [==============================] - 31s 203ms/step - loss: 0.3772 - accuracy: 0.8878 - val_loss: 0.8912 - val_accuracy: 0.7578
# Epoch 6/50
# 153/153 [==============================] - 31s 203ms/step - loss: 0.2874 - accuracy: 0.9153 - val_loss: 0.9595 - val_accuracy: 0.7534
# Epoch 7/50
# ...

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=None,
    #shear_range=10.0,
    #zoom_range=0.1,
    vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=25, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Epoch 1/25
# 153/153 [==============================] - 54s 337ms/step - loss: 2.3556 - accuracy: 0.4407 - val_loss: 1.4898 - val_accuracy: 0.5961
# Epoch 2/25
# 153/153 [==============================] - 51s 331ms/step - loss: 1.1750 - accuracy: 0.6879 - val_loss: 1.1577 - val_accuracy: 0.6823
# Epoch 3/25
# 153/153 [==============================] - 51s 330ms/step - loss: 0.9109 - accuracy: 0.7405 - val_loss: 1.0287 - val_accuracy: 0.7154
# Epoch 4/25
# 153/153 [==============================] - 50s 330ms/step - loss: 0.7094 - accuracy: 0.7979 - val_loss: 0.9998 - val_accuracy: 0.7310
# Epoch 5/25
# 153/153 [==============================] - 51s 332ms/step - loss: 0.6263 - accuracy: 0.8162 - val_loss: 0.9873 - val_accuracy: 0.7403
# Epoch 6/25
# 153/153 [==============================] - 50s 330ms/step - loss: 0.5481 - accuracy: 0.8398 - val_loss: 0.9390 - val_accuracy: 0.7403
# Epoch 7/25
# ...

# %%
def make_model(learning_rate=0.01, size_inner=100, droprate=0.5):
        base_model = Xception(weights='imagenet', input_shape=(150, 150, 3), include_top=False)
        base_model.trainable=False
        inputs = keras.Input(shape=(150, 150, 3))
        base = base_model(inputs, training=False)
        vectors = keras.layers.GlobalAveragePooling2D()(base)
        inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
        drop = keras.layers.Dropout(droprate)(inner)
        outputs = keras.layers.Dense(102)(drop)
        model = keras.Model(inputs, outputs)
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        loss = keras.losses.CategoricalCrossentropy(from_logits=True)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        return model

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=None,
    shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False)

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 54s 341ms/step - loss: 2.1625 - accuracy: 0.4858 - val_loss: 1.2687 - val_accuracy: 0.6586
# Epoch 2/50
# 153/153 [==============================] - 50s 324ms/step - loss: 0.8993 - accuracy: 0.7536 - val_loss: 1.1111 - val_accuracy: 0.7072
# Epoch 3/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.5569 - accuracy: 0.8428 - val_loss: 1.0593 - val_accuracy: 0.7222
# Epoch 4/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.4068 - accuracy: 0.8865 - val_loss: 0.8882 - val_accuracy: 0.7678
# Epoch 5/50
# 153/153 [==============================] - 49s 321ms/step - loss: 0.2879 - accuracy: 0.9198 - val_loss: 0.8879 - val_accuracy: 0.7659
# Epoch 6/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.2276 - accuracy: 0.9358 - val_loss: 0.9976 - val_accuracy: 0.7478
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=None,
    #shear_range=10.0,
    zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False)

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 52s 328ms/step - loss: 2.2231 - accuracy: 0.4838 - val_loss: 1.3175 - val_accuracy: 0.6685
# Epoch 2/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.9136 - accuracy: 0.7392 - val_loss: 1.1065 - val_accuracy: 0.7016
# Epoch 3/50
# 153/153 [==============================] - 50s 325ms/step - loss: 0.5967 - accuracy: 0.8275 - val_loss: 0.9771 - val_accuracy: 0.7328
# Epoch 4/50
# 153/153 [==============================] - 51s 336ms/step - loss: 0.4272 - accuracy: 0.8746 - val_loss: 0.9551 - val_accuracy: 0.7341
# Epoch 5/50
# 153/153 [==============================] - 49s 323ms/step - loss: 0.3199 - accuracy: 0.9052 - val_loss: 0.9570 - val_accuracy: 0.7491
# Epoch 6/50
# 153/153 [==============================] - 50s 327ms/step - loss: 0.2343 - accuracy: 0.9346 - val_loss: 0.8902 - val_accuracy: 0.7640
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=None,
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False)

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 52s 328ms/step - loss: 2.2267 - accuracy: 0.4764 - val_loss: 1.3129 - val_accuracy: 0.6523
# Epoch 2/50
# 153/153 [==============================] - 51s 336ms/step - loss: 0.8987 - accuracy: 0.7583 - val_loss: 1.0866 - val_accuracy: 0.7116
# Epoch 3/50
# 153/153 [==============================] - 49s 321ms/step - loss: 0.5835 - accuracy: 0.8365 - val_loss: 0.9498 - val_accuracy: 0.7434
# Epoch 4/50
# 153/153 [==============================] - 49s 319ms/step - loss: 0.4239 - accuracy: 0.8753 - val_loss: 0.9156 - val_accuracy: 0.7459
# Epoch 5/50
# 153/153 [==============================] - 49s 321ms/step - loss: 0.3016 - accuracy: 0.9161 - val_loss: 0.8890 - val_accuracy: 0.7609
# Epoch 6/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.2528 - accuracy: 0.9309 - val_loss: 0.8535 - val_accuracy: 0.7772
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    height_shift_range=10.0,
    #brightness_range=None,
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False)

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 52s 325ms/step - loss: 2.1597 - accuracy: 0.4834 - val_loss: 1.2357 - val_accuracy: 0.6579
# Epoch 2/50
# 153/153 [==============================] - 49s 322ms/step - loss: 0.8978 - accuracy: 0.7544 - val_loss: 1.0033 - val_accuracy: 0.7297
# Epoch 3/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.6113 - accuracy: 0.8227 - val_loss: 1.0118 - val_accuracy: 0.7235
# Epoch 4/50
# 153/153 [==============================] - 49s 322ms/step - loss: 0.3975 - accuracy: 0.8839 - val_loss: 0.8669 - val_accuracy: 0.7534
# Epoch 5/50
# 153/153 [==============================] - 50s 328ms/step - loss: 0.2992 - accuracy: 0.9169 - val_loss: 0.9055 - val_accuracy: 0.7647
# Epoch 6/50
# 153/153 [==============================] - 51s 333ms/step - loss: 0.2380 - accuracy: 0.9331 - val_loss: 0.9200 - val_accuracy: 0.7603
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    brightness_range=[0.7, 1.3],
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(150, 150), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(150, 150), batch_size=32, shuffle=False)

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds)
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 37s 227ms/step - loss: 2.1107 - accuracy: 0.4951 - val_loss: 1.2735 - val_accuracy: 0.6542
# Epoch 2/50
# 153/153 [==============================] - 33s 216ms/step - loss: 0.8180 - accuracy: 0.7762 - val_loss: 1.0274 - val_accuracy: 0.7197
# Epoch 3/50
# 153/153 [==============================] - 33s 216ms/step - loss: 0.4641 - accuracy: 0.8644 - val_loss: 1.0434 - val_accuracy: 0.7228
# Epoch 4/50
# 153/153 [==============================] - 34s 219ms/step - loss: 0.2955 - accuracy: 0.9190 - val_loss: 0.9672 - val_accuracy: 0.7409
# Epoch 5/50
# 153/153 [==============================] - 35s 228ms/step - loss: 0.1989 - accuracy: 0.9479 - val_loss: 0.9589 - val_accuracy: 0.7441
# Epoch 6/50
# 153/153 [==============================] - 35s 227ms/step - loss: 0.1323 - accuracy: 0.9684 - val_loss: 0.9489 - val_accuracy: 0.7722
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Training a larger model

# %%
def make_model(learning_rate=0.01, size_inner=100, droprate=0.5):
        base_model = Xception(weights='imagenet', input_shape=(299, 299, 3), include_top=False)
        base_model.trainable=False
        inputs = keras.Input(shape=(299, 299, 3))
        base = base_model(inputs, training=False)
        vectors = keras.layers.GlobalAveragePooling2D()(base)
        inner = keras.layers.Dense(size_inner, activation='relu')(vectors)
        drop = keras.layers.Dropout(droprate)(inner)
        outputs = keras.layers.Dense(102)(drop)
        model = keras.Model(inputs, outputs)
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        loss = keras.losses.CategoricalCrossentropy(from_logits=True)
        model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
        return model

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=[0.7, 1.3],
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(299, 299), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(299, 299), batch_size=32, shuffle=False)

checkpoint = keras.callbacks.ModelCheckpoint('xception_{epoch:02d}_{val_accuracy:.3f}.h5',
                                            save_best_only=True,
                                            monitor='val_accuracy',
                                            mode='max')

learning_rate = 0.001
size = 1000
droprate = 0.0
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=[checkpoint])
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 51s 321ms/step - loss: 1.9877 - accuracy: 0.5515 - val_loss: 0.9556 - val_accuracy: 0.7603
# Epoch 2/50
# 153/153 [==============================] - 50s 324ms/step - loss: 0.5419 - accuracy: 0.8636 - val_loss: 0.5968 - val_accuracy: 0.8483
# Epoch 3/50
# 153/153 [==============================] - 50s 327ms/step - loss: 0.2861 - accuracy: 0.9268 - val_loss: 0.5221 - val_accuracy: 0.8571
# Epoch 4/50
# 153/153 [==============================] - 51s 330ms/step - loss: 0.1629 - accuracy: 0.9651 - val_loss: 0.5156 - val_accuracy: 0.8564
# Epoch 5/50
# 153/153 [==============================] - 52s 336ms/step - loss: 0.0892 - accuracy: 0.9834 - val_loss: 0.4455 - val_accuracy: 0.8789
# Epoch 6/50
# 153/153 [==============================] - 52s 336ms/step - loss: 0.0622 - accuracy: 0.9899 - val_loss: 0.4275 - val_accuracy: 0.8795
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Trying larger model with dropout

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=[0.7, 1.3],
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(299, 299), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(299, 299), batch_size=32, shuffle=False)

checkpoint = keras.callbacks.ModelCheckpoint('xception_{epoch:02d}_{val_accuracy:.3f}.h5',
                                            save_best_only=True,
                                            monitor='val_accuracy',
                                            mode='max')

learning_rate = 0.001
size = 1000
droprate = 0.2
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=[checkpoint])
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 50s 313ms/step - loss: 2.1732 - accuracy: 0.5057 - val_loss: 0.9991 - val_accuracy: 0.7572
# Epoch 2/50
# 153/153 [==============================] - 48s 316ms/step - loss: 0.6796 - accuracy: 0.8229 - val_loss: 0.6661 - val_accuracy: 0.8265
# Epoch 3/50
# 153/153 [==============================] - 49s 320ms/step - loss: 0.3751 - accuracy: 0.9048 - val_loss: 0.5578 - val_accuracy: 0.8464
# Epoch 4/50
# 153/153 [==============================] - 50s 328ms/step - loss: 0.2520 - accuracy: 0.9370 - val_loss: 0.4965 - val_accuracy: 0.8658
# Epoch 5/50
# 153/153 [==============================] - 50s 324ms/step - loss: 0.1645 - accuracy: 0.9637 - val_loss: 0.4904 - val_accuracy: 0.8614
# Epoch 6/50
# 153/153 [==============================] - 51s 331ms/step - loss: 0.1123 - accuracy: 0.9754 - val_loss: 0.4279 - val_accuracy: 0.8783
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    #rotation_range=30,
    #width_shift_range=10.0,
    #height_shift_range=10.0,
    #brightness_range=[0.7, 1.3],
    #shear_range=10.0,
    #zoom_range=0.1,
    #vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(299, 299), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(299, 299), batch_size=32, shuffle=False)

checkpoint = keras.callbacks.ModelCheckpoint('xception_{epoch:02d}_{val_accuracy:.3f}.h5',
                                            save_best_only=True,
                                            monitor='val_accuracy',
                                            mode='max')

learning_rate = 0.001
size = 1000
droprate = 0.4
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=[checkpoint])
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 51s 318ms/step - loss: 2.4363 - accuracy: 0.4467 - val_loss: 1.1438 - val_accuracy: 0.7191
# Epoch 2/50
# 153/153 [==============================] - 49s 322ms/step - loss: 0.8701 - accuracy: 0.7694 - val_loss: 0.7487 - val_accuracy: 0.8215
# Epoch 3/50
# 153/153 [==============================] - 51s 335ms/step - loss: 0.5497 - accuracy: 0.8576 - val_loss: 0.5895 - val_accuracy: 0.8446
# Epoch 4/50
# 153/153 [==============================] - 52s 337ms/step - loss: 0.3866 - accuracy: 0.8933 - val_loss: 0.5717 - val_accuracy: 0.8496
# Epoch 5/50
# 153/153 [==============================] - 52s 341ms/step - loss: 0.2771 - accuracy: 0.9286 - val_loss: 0.4762 - val_accuracy: 0.8733
# Epoch 6/50
# 153/153 [==============================] - 53s 345ms/step - loss: 0.1900 - accuracy: 0.9532 - val_loss: 0.4614 - val_accuracy: 0.8777
# Epoch 7/50
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Larger model with augmentation

# %%
train_gen = ImageDataGenerator(
     preprocessing_function=preprocess_input,
    zoom_range=0.2,
)

train_ds = train_gen.flow_from_directory(
    './split/train', seed=42, target_size=(299, 299), batch_size=32, class_mode='categorical')

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_ds = val_gen.flow_from_directory('./split/val', seed=42, target_size=(299, 299), batch_size=32, shuffle=False)

checkpoint = keras.callbacks.ModelCheckpoint('xception_{epoch:02d}_{val_accuracy:.3f}.h5',
                                            save_best_only=True,
                                            monitor='val_accuracy',
                                            mode='max')

learning_rate = 0.001
size = 1000
droprate = 0.2
model = make_model(learning_rate=learning_rate, size_inner=size, droprate=droprate)
info = model.fit(train_ds, epochs=50, validation_data=val_ds, callbacks=[checkpoint])
scores = info.history
# Out:
# Found 4874 images belonging to 102 classes.
# Found 1602 images belonging to 102 classes.
# Epoch 1/50
# 153/153 [==============================] - 115s 739ms/step - loss: 2.4507 - accuracy: 0.4411 - val_loss: 1.2112 - val_accuracy: 0.7116
# Epoch 2/50
# 153/153 [==============================] - 113s 736ms/step - loss: 0.9222 - accuracy: 0.7565 - val_loss: 0.7719 - val_accuracy: 0.8021
# Epoch 3/50
# 153/153 [==============================] - 113s 736ms/step - loss: 0.5947 - accuracy: 0.8451 - val_loss: 0.6114 - val_accuracy: 0.8327
# Epoch 4/50
# 153/153 [==============================] - 113s 734ms/step - loss: 0.4475 - accuracy: 0.8775 - val_loss: 0.5546 - val_accuracy: 0.8471
# Epoch 5/50
# 153/153 [==============================] - 112s 733ms/step - loss: 0.3520 - accuracy: 0.9042 - val_loss: 0.4997 - val_accuracy: 0.8633
# Epoch 6/50
# 153/153 [==============================] - 112s 734ms/step - loss: 0.2818 - accuracy: 0.9218 - val_loss: 0.5124 - val_accuracy: 0.8639
# ...

# %%
plt.plot(scores['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
